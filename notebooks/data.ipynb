# %% [markdown]
# # Look ESC-50 data

# %% [markdown]
# [ESC-50](https://github.com/karoldvl/ESC-50)

# %% [markdown]
# ## Settings

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import librosa
import librosa.display

import IPython.display as ipd

# %%
sys.path.append('../src/')

import utils
import preprocess
from visualize import visualize_spectrogram

# %%
data_dir = Path().cwd().parent/'data'
raw_data_dir = data_dir/'external'/'ESC-50'
processed_data_dir = data_dir/'processed'/'ESC-50'

# %%
metadata_path = raw_data_dir/'meta'/'esc50.csv'
audio_dir = raw_data_dir/'audio'
spectrogram_dir = processed_data_dir/'spectrogram'

# %% [markdown]
# ## Load Metadata

# %%
metadata = pd.read_csv(str(metadata_path))

# %%
metadata
# Out:
#                filename  fold  target          category  esc10  src_file take
# 0      1-100032-A-0.wav     1       0               dog   True    100032    A
# 1     1-100038-A-14.wav     1      14    chirping_birds  False    100038    A
# 2     1-100210-A-36.wav     1      36    vacuum_cleaner  False    100210    A
# 3     1-100210-B-36.wav     1      36    vacuum_cleaner  False    100210    B
# 4     1-101296-A-19.wav     1      19      thunderstorm  False    101296    A
# 5     1-101296-B-19.wav     1      19      thunderstorm  False    101296    B
# 6     1-101336-A-30.wav     1      30   door_wood_knock  False    101336    A
# 7     1-101404-A-34.wav     1      34       can_opening  False    101404    A
# 8      1-103298-A-9.wav     1       9              crow  False    103298    A
# 9     1-103995-A-30.wav     1      30   door_wood_knock  False    103995    A
# 10    1-103999-A-30.wav     1      30   door_wood_knock  False    103999    A
# 11    1-104089-A-22.wav     1      22          clapping  False    104089    A
# 12    1-104089-B-22.wav     1      22          clapping  False    104089    B
# 13    1-105224-A-22.wav     1      22          clapping  False    105224    A
# 14     1-110389-A-0.wav     1       0               dog   True    110389    A
# 15    1-110537-A-22.wav     1      22          clapping  False    110537    A
# 16    1-115521-A-19.wav     1      19      thunderstorm  False    115521    A
# 17    1-115545-A-48.wav     1      48         fireworks  False    115545    A
# 18    1-115545-B-48.wav     1      48         fireworks  False    115545    B
# 19    1-115545-C-48.wav     1      48         fireworks  False    115545    C
# 20    1-115546-A-48.wav     1      48         fireworks  False    115546    A
# 21    1-115920-A-22.wav     1      22          clapping  False    115920    A
# 22    1-115920-B-22.wav     1      22          clapping  False    115920    B
# 23    1-115921-A-22.wav     1      22          clapping  False    115921    A
# 24    1-116765-A-41.wav     1      41          chainsaw   True    116765    A
# 25     1-11687-A-47.wav     1      47          airplane  False     11687    A
# 26    1-118206-A-31.wav     1      31       mouse_click  False    118206    A
# 27    1-118559-A-17.wav     1      17     pouring_water  False    118559    A
# 28    1-119125-A-45.wav     1      45             train  False    119125    A
# 29     1-121951-A-8.wav     1       8             sheep  False    121951    A
# ...                 ...   ...     ...               ...    ...       ...  ...
# 1970  5-257349-A-15.wav     5      15       water_drops  False    257349    A
# 1971  5-257642-A-39.wav     5      39    glass_breaking  False    257642    A
# 1972  5-257839-A-14.wav     5      14    chirping_birds  False    257839    A
# 1973   5-259169-A-5.wav     5       5               cat  False    259169    A
# 1974  5-259180-A-15.wav     5      15       water_drops  False    259180    A
# 1975  5-259514-A-26.wav     5      26          laughing  False    259514    A
# 1976  5-259640-A-29.wav     5      29  drinking_sipping  False    259640    A
# 1977  5-260011-A-34.wav     5      34       can_opening  False    260011    A
# 1978  5-260164-A-23.wav     5      23         breathing  False    260164    A
# 1979  5-260432-A-39.wav     5      39    glass_breaking  False    260432    A
# 1980  5-260433-A-39.wav     5      39    glass_breaking  False    260433    A
# 1981  5-260434-A-39.wav     5      39    glass_breaking  False    260434    A
# 1982  5-260875-A-35.wav     5      35   washing_machine  False    260875    A
# 1983   5-261325-A-9.wav     5       9              crow  False    261325    A
# 1984  5-261433-A-15.wav     5      15       water_drops  False    261433    A
# 1985  5-261439-A-15.wav     5      15       water_drops  False    261439    A
# 1986  5-261464-A-23.wav     5      23         breathing  False    261464    A
# 1987  5-262641-A-15.wav     5      15       water_drops  False    262641    A
# 1988  5-262957-A-22.wav     5      22          clapping  False    262957    A
# 1989  5-263490-A-25.wav     5      25         footsteps  False    263490    A
# 1990  5-263491-A-25.wav     5      25         footsteps  False    263491    A
# 1991  5-263501-A-25.wav     5      25         footsteps  False    263501    A
# 1992  5-263775-A-26.wav     5      26          laughing  False    263775    A
# 1993  5-263775-B-26.wav     5      26          laughing  False    263775    B
# 1994   5-263831-A-6.wav     5       6               hen  False    263831    A
# 1995   5-263831-B-6.wav     5       6               hen  False    263831    B
# 1996  5-263902-A-36.wav     5      36    vacuum_cleaner  False    263902    A
# 1997   5-51149-A-25.wav     5      25         footsteps  False     51149    A
# 1998    5-61635-A-8.wav     5       8             sheep  False     61635    A
# 1999     5-9032-A-0.wav     5       0               dog   True      9032    A
#
# [2000 rows x 7 columns]

# %%
n_data = len(metadata)
print('#Data: {}'.format(n_data))
# Out:
# #Data: 2000

# %%
label_data = metadata.loc[:, ['target', 'category']].drop_duplicates()
label_data = label_data.sort_values(by=['target'], ascending=True)
label_data = label_data.reset_index(drop=True)
#label_data

# %%
label_data['number'] = 0
for i, target in enumerate(label_data['target']):
    label_data.loc[i, 'number'] = len(metadata.query('target == @target'))
label_data
# Out:
#     target          category  number
# 0        0               dog      40
# 1        1           rooster      40
# 2        2               pig      40
# 3        3               cow      40
# 4        4              frog      40
# 5        5               cat      40
# 6        6               hen      40
# 7        7           insects      40
# 8        8             sheep      40
# 9        9              crow      40
# 10      10              rain      40
# 11      11         sea_waves      40
# 12      12    crackling_fire      40
# 13      13          crickets      40
# 14      14    chirping_birds      40
# 15      15       water_drops      40
# 16      16              wind      40
# 17      17     pouring_water      40
# 18      18      toilet_flush      40
# 19      19      thunderstorm      40
# 20      20       crying_baby      40
# 21      21          sneezing      40
# 22      22          clapping      40
# 23      23         breathing      40
# 24      24          coughing      40
# 25      25         footsteps      40
# 26      26          laughing      40
# 27      27    brushing_teeth      40
# 28      28           snoring      40
# 29      29  drinking_sipping      40
# 30      30   door_wood_knock      40
# 31      31       mouse_click      40
# 32      32   keyboard_typing      40
# 33      33  door_wood_creaks      40
# 34      34       can_opening      40
# 35      35   washing_machine      40
# 36      36    vacuum_cleaner      40
# 37      37       clock_alarm      40
# 38      38        clock_tick      40
# 39      39    glass_breaking      40
# 40      40        helicopter      40
# 41      41          chainsaw      40
# 42      42             siren      40
# 43      43          car_horn      40
# 44      44            engine      40
# 45      45             train      40
# 46      46      church_bells      40
# 47      47          airplane      40
# 48      48         fireworks      40
# 49      49          hand_saw      40

# %% [markdown]
# ## Load

# %%
idx = 5

# %%
data = metadata.iloc[idx, :]

# %%
data
# Out:
# filename    1-101296-B-19.wav
# fold                        1
# target                     19
# category         thunderstorm
# esc10                   False
# src_file               101296
# take                        B
# Name: 5, dtype: object

# %%
fpath = audio_dir/data['filename']

# %%
x, fs = librosa.load(str(fpath))

# %%
x.shape
# Out:
# (110250,)

# %%
fs
# Out:
# 22050

# %%
plt.plot(x)
plt.show()

# %%
ipd.Audio(x, rate=fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Spectrogram

# %%
sp = preprocess.spectrogram(x)
sp.shape
# Out:
# (257, 431)

# %%
visualize_spectrogram(sp, fs, hop_length=256, mel=False)

# %% [markdown]
# ## Mel Spectrogram

# %%
melsp = preprocess.mel_spectrogram(x)
melsp.shape
# Out:
# (128, 862)

# %%
visualize_spectrogram(melsp, fs, mel=True)

# %% [markdown]
# ## Data Augmantation

# %% [markdown]
# ## train/valid/test split

# %%
train_metadata_path = processed_data_dir/'metadata_train.csv'
valid_metadata_path = processed_data_dir/'metadata_valid.csv'
test_metadata_path = processed_data_dir/'metadata_test.csv'

# %%
metadata
# Out:
#                filename  fold  target          category  esc10  src_file take
# 0      1-100032-A-0.wav     1       0               dog   True    100032    A
# 1     1-100038-A-14.wav     1      14    chirping_birds  False    100038    A
# 2     1-100210-A-36.wav     1      36    vacuum_cleaner  False    100210    A
# 3     1-100210-B-36.wav     1      36    vacuum_cleaner  False    100210    B
# 4     1-101296-A-19.wav     1      19      thunderstorm  False    101296    A
# 5     1-101296-B-19.wav     1      19      thunderstorm  False    101296    B
# 6     1-101336-A-30.wav     1      30   door_wood_knock  False    101336    A
# 7     1-101404-A-34.wav     1      34       can_opening  False    101404    A
# 8      1-103298-A-9.wav     1       9              crow  False    103298    A
# 9     1-103995-A-30.wav     1      30   door_wood_knock  False    103995    A
# 10    1-103999-A-30.wav     1      30   door_wood_knock  False    103999    A
# 11    1-104089-A-22.wav     1      22          clapping  False    104089    A
# 12    1-104089-B-22.wav     1      22          clapping  False    104089    B
# 13    1-105224-A-22.wav     1      22          clapping  False    105224    A
# 14     1-110389-A-0.wav     1       0               dog   True    110389    A
# 15    1-110537-A-22.wav     1      22          clapping  False    110537    A
# 16    1-115521-A-19.wav     1      19      thunderstorm  False    115521    A
# 17    1-115545-A-48.wav     1      48         fireworks  False    115545    A
# 18    1-115545-B-48.wav     1      48         fireworks  False    115545    B
# 19    1-115545-C-48.wav     1      48         fireworks  False    115545    C
# 20    1-115546-A-48.wav     1      48         fireworks  False    115546    A
# 21    1-115920-A-22.wav     1      22          clapping  False    115920    A
# 22    1-115920-B-22.wav     1      22          clapping  False    115920    B
# 23    1-115921-A-22.wav     1      22          clapping  False    115921    A
# 24    1-116765-A-41.wav     1      41          chainsaw   True    116765    A
# 25     1-11687-A-47.wav     1      47          airplane  False     11687    A
# 26    1-118206-A-31.wav     1      31       mouse_click  False    118206    A
# 27    1-118559-A-17.wav     1      17     pouring_water  False    118559    A
# 28    1-119125-A-45.wav     1      45             train  False    119125    A
# 29     1-121951-A-8.wav     1       8             sheep  False    121951    A
# ...                 ...   ...     ...               ...    ...       ...  ...
# 1970  5-257349-A-15.wav     5      15       water_drops  False    257349    A
# 1971  5-257642-A-39.wav     5      39    glass_breaking  False    257642    A
# 1972  5-257839-A-14.wav     5      14    chirping_birds  False    257839    A
# 1973   5-259169-A-5.wav     5       5               cat  False    259169    A
# 1974  5-259180-A-15.wav     5      15       water_drops  False    259180    A
# 1975  5-259514-A-26.wav     5      26          laughing  False    259514    A
# 1976  5-259640-A-29.wav     5      29  drinking_sipping  False    259640    A
# 1977  5-260011-A-34.wav     5      34       can_opening  False    260011    A
# 1978  5-260164-A-23.wav     5      23         breathing  False    260164    A
# 1979  5-260432-A-39.wav     5      39    glass_breaking  False    260432    A
# 1980  5-260433-A-39.wav     5      39    glass_breaking  False    260433    A
# 1981  5-260434-A-39.wav     5      39    glass_breaking  False    260434    A
# 1982  5-260875-A-35.wav     5      35   washing_machine  False    260875    A
# 1983   5-261325-A-9.wav     5       9              crow  False    261325    A
# 1984  5-261433-A-15.wav     5      15       water_drops  False    261433    A
# 1985  5-261439-A-15.wav     5      15       water_drops  False    261439    A
# 1986  5-261464-A-23.wav     5      23         breathing  False    261464    A
# 1987  5-262641-A-15.wav     5      15       water_drops  False    262641    A
# 1988  5-262957-A-22.wav     5      22          clapping  False    262957    A
# 1989  5-263490-A-25.wav     5      25         footsteps  False    263490    A
# 1990  5-263491-A-25.wav     5      25         footsteps  False    263491    A
# 1991  5-263501-A-25.wav     5      25         footsteps  False    263501    A
# 1992  5-263775-A-26.wav     5      26          laughing  False    263775    A
# 1993  5-263775-B-26.wav     5      26          laughing  False    263775    B
# 1994   5-263831-A-6.wav     5       6               hen  False    263831    A
# 1995   5-263831-B-6.wav     5       6               hen  False    263831    B
# 1996  5-263902-A-36.wav     5      36    vacuum_cleaner  False    263902    A
# 1997   5-51149-A-25.wav     5      25         footsteps  False     51149    A
# 1998    5-61635-A-8.wav     5       8             sheep  False     61635    A
# 1999     5-9032-A-0.wav     5       0               dog   True      9032    A
#
# [2000 rows x 7 columns]

# %%
label_data
# Out:
#     target          category  number
# 0        0               dog      40
# 1        1           rooster      40
# 2        2               pig      40
# 3        3               cow      40
# 4        4              frog      40
# 5        5               cat      40
# 6        6               hen      40
# 7        7           insects      40
# 8        8             sheep      40
# 9        9              crow      40
# 10      10              rain      40
# 11      11         sea_waves      40
# 12      12    crackling_fire      40
# 13      13          crickets      40
# 14      14    chirping_birds      40
# 15      15       water_drops      40
# 16      16              wind      40
# 17      17     pouring_water      40
# 18      18      toilet_flush      40
# 19      19      thunderstorm      40
# 20      20       crying_baby      40
# 21      21          sneezing      40
# 22      22          clapping      40
# 23      23         breathing      40
# 24      24          coughing      40
# 25      25         footsteps      40
# 26      26          laughing      40
# 27      27    brushing_teeth      40
# 28      28           snoring      40
# 29      29  drinking_sipping      40
# 30      30   door_wood_knock      40
# 31      31       mouse_click      40
# 32      32   keyboard_typing      40
# 33      33  door_wood_creaks      40
# 34      34       can_opening      40
# 35      35   washing_machine      40
# 36      36    vacuum_cleaner      40
# 37      37       clock_alarm      40
# 38      38        clock_tick      40
# 39      39    glass_breaking      40
# 40      40        helicopter      40
# 41      41          chainsaw      40
# 42      42             siren      40
# 43      43          car_horn      40
# 44      44            engine      40
# 45      45             train      40
# 46      46      church_bells      40
# 47      47          airplane      40
# 48      48         fireworks      40
# 49      49          hand_saw      40

# %%
labels = label_data['target'].values
n_label = len(labels)
label_indices_shuffled = np.random.permutation(range(n_label))

# %% [markdown]
# ### Test data

# %% [markdown]
# only unknown label data

# %%
n_test_label = 5

# %%
test_label_indices = label_indices_shuffled[:n_test_label]
test_labels = labels[test_label_indices]
test_labels
# Out:
# array([15, 34, 29, 12, 20], dtype=int64)

# %%
test_indices = []
for label in test_labels:
    test_indices.extend(metadata.query('target == @label').index.values.tolist())
test_metadata = metadata.loc[test_indices, :]
test_metadata.to_csv(str(test_metadata_path), index=False, encoding='utf-8')
#test_metadata

# %% [markdown]
# ### Valid data

# %% [markdown]
# unknown label data + known label data

# %%
n_only_valid_label = 2
n_known_label_data = 120

# %%
valid_label_indices = label_indices_shuffled[n_test_label:n_test_label+n_only_valid_label]
valid_labels = labels[valid_label_indices]
valid_labels
# Out:
# array([19,  1], dtype=int64)

# %%
valid_only_indices = []
for label in valid_labels:
    valid_only_indices.extend(metadata.query('target == @label').index.values.tolist())

# %%
indices_all = metadata.index.values.tolist()
indices_left = list(set(indices_all) - set(valid_only_indices) - set(test_indices))

# %%
_indices = np.random.permutation(range(len(indices_left)))[:n_known_label_data]
valid_known_indices = np.array(indices_left)[_indices].tolist()

# %%
valid_indices = valid_only_indices + valid_known_indices

# %%
valid_metadata = metadata.loc[valid_indices, :]
valid_metadata.to_csv(str(valid_metadata_path), index=False, encoding='utf-8')
#valid_metadata

# %% [markdown]
# ### Train data

# %%
train_metadata = metadata.drop(test_indices, axis=0).drop(valid_indices, axis=0)
train_metadata.to_csv(str(train_metadata_path), index=False, encoding='utf-8')
#train_metadata
